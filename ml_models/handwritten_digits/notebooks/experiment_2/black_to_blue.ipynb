# %%
import cv2

# %%
def get_mask(img):
#     print(img)
    image = img
#     image = cv2.imread(img, cv2.IMREAD_UNCHANGED)    
    #make mask of where the transparent bits are
    trans_mask = image[:,:,3] == 0
    #replace areas of transparency with white and not transparent
    image[trans_mask] = [255, 255, 255, 255]
    #new image without alpha channel...
    new_img = cv2.cvtColor(image, cv2.COLOR_BGRA2BGR)
    return new_img

# %%
img = cv2.imread("/home/venkateshiyer/handwritten_digits_test/0/hsf_0_00001.png")
# mask_img = get_mask(img)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# blur = cv2.blur(gray, (10,10))
# cv2.imshow('gray', gray)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
ret, thresh = cv2.threshold(gray, 1, 255, cv2.THRESH_OTSU)

# cv2.imshow('thresh', thresh)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
contours, heirarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# contours, hier = cv2.findContours(edgedImage.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
# print("These are countours", contours)
# print("len of contours", len(contours))
# conts = contours[-1]



# image = cv2.imread('1.png')
# gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# cnts = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# cnts = cnts[0] if len(cnts) == 2 else cnts[1]

# for c in cnts:
#     cv2.drawContours(gray,[c], 0, (255,255,255), -1)

# kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (20,20))
# opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel, iterations=2)

# cv2.imshow('gray', gray)
# cv2.imshow('opening', opening)
# cv2.imwrite('opening.png', opening)
# cv2.waitKey(0)
conts = contours[-1]
cv2.drawContours(thresh, conts, -1, (0,255,0), 1)
print("This is conts", conts)
cv2.fillPoly(img, pts=[conts], color =(255,0,0))
# cv2.namedWindow('Contours',cv2.WINDOW_NORMAL)
# cv2.namedWindow('Thresh',cv2.WINDOW_NORMAL)
# cv2.imshow('Contours', img)
cv2.imshow('img', img)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# This is conts [[[68 53]]
#
#  [[68 57]]
#
#  [[64 61]]
#
#  [[63 61]]
#
#  [[62 62]]
#
#  [[61 61]]
#
#  [[61 58]]
#
#  [[59 58]]
#
#  [[59 59]]
#
#  [[57 61]]
#
#  [[56 61]]
#
#  [[54 63]]
#
#  [[53 63]]
#
#  [[53 67]]
#
#  [[52 68]]
#
#  [[52 70]]
#
#  [[53 71]]
#
#  [[53 72]]
#
#  [[56 72]]
#
#  [[57 73]]
#
#  [[58 73]]
#
#  [[59 72]]
#
#  [[63 72]]
#
#  [[65 70]]
#
#  [[66 70]]
#
#  [[69 67]]
#
#  [[69 66]]
#
#  [[70 65]]
#
#  [[70 60]]
#
#  [[69 59]]
#
#  [[69 53]]]
