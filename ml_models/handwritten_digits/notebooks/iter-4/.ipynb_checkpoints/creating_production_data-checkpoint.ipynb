# %%
import json
import base64
import os
from PIL import Image
from io import BytesIO
import numpy as np
import cv2

# %%
def get_length(data):
    return len(data)

# %%
# path = The path to the save json files of training data
path = os.path.expanduser('~')+'/Desktop/check_json/'
for json_file in os.listdir(path):
    name_json = json_file.split('.')[0]
    path_jsonfile = path+json_file
    f = open(path_jsonfile)
    data = json.load(f)
    length = get_length(data)
    for student in range(0,length):
        for i, base64string in enumerate(data[student]['studentIdTrainingData']):
            im = Image.open(BytesIO(base64.b64decode(base64string)))
            im = im.resize((28,28))
            im.save(os.path.expanduser('~')+'/Desktop/check_images/'+name_json+str(student)+str(i)+".png",'PNG')
print('Production dataset created!')

# %% [markdown]
# # Experiments

# %%
import tensorflow as tf
model = tf.keras.models.load_model("/home/venkateshiyer/react-native-saral-sdk/ml_models/handwritten_digits/models/pre-trained_model/saral_hwd_model_itr3.h5")
# Out:
# 2023-02-06 11:45:33.024087: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-06 11:45:33.024117: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-06 11:45:35.234094: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-06 11:45:35.234147: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ti-lap-492): /proc/driver/nvidia/version does not exist
# ...

# %%
import cv2
import numpy as np 
import glob

# %%
path = "/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/production/*"
for img1 in sorted(glob.iglob(path)):
    img=cv2.imread(img1)
    img_name = img1.split("/")[-1]
    img_write = img
#     print('this is img write', type(img_write))
#     img=cv2.resize(img,(28,28))
    img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = img.astype('float32') / 255.
    img= np.reshape(img,(1,28,28,1))
    res=model.predict(img)
    pred=res[0].argmax(axis=0)
    print(type(pred))
    if pred == 0:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/0/'+img_name, img_write)
    elif pred ==1:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/1/'+img_name, img_write)
    elif pred ==2:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/2/'+img_name, img_write)
    elif pred ==3:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/3/'+img_name, img_write)
    elif pred ==4:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/4/'+img_name, img_write)
    elif pred ==5:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/5/'+img_name, img_write)
    elif pred ==6:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/6/'+img_name, img_write)
    elif pred ==7:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/7/'+img_name, img_write)
    elif pred ==8:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/8/'+img_name, img_write)
    elif pred ==9:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/9/'+img_name, img_write)
    else:
        cv2.imwrite('/home/venkateshiyer/Desktop/fulljson_Aug923/testing_dataset/class_wise/10/'+img_name, img_write)
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# ...

# %%
# path = The path to the save json files of training data
path = os.path.expanduser('~')+'/Desktop/production_dataset_01_23/'
for json_file in os.listdir(path):
    name_json = json_file.split('.')[0]
    path_jsonfile = path+json_file
    f = open(path_jsonfile)
    data = json.load(f)
    length = get_length(data)
    for student in range(0,length):
        for i, base64string in enumerate(data[student]['studentIdTrainingData']):
            print("This is base 64 string", base64string)
            im = Image.open(BytesIO(base64.b64decode(base64string)))
            print("This is string", pytesseract.image_to_string(im))
#             im = im.resize((28,28))
            im = cv2.resize(im, (28, 28))
            img= cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
            img= np.reshape(img,(1,28,28,1))
            res=model.predict(img)
            pred=res[0].argmax(axis=0)
            print("This is predictions", pred)
#             im.save(os.path.expanduser('~')+'/handwritten_dataset/prod_dataset_iter4/'+name_json+str(student)+str(i)+".png",'PNG')
print('Production dataset created!')
# Out:
# This is base 64 string /9j/4AAQSkZJRgABAQAAAQABAAD/4gIoSUNDX1BST0ZJTEUAAQEAAAIYAAAAAAQwAABtbnRyUkdC
# IFhZWiAAAAAAAAAAAAAAAABhY3NwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAQAA9tYAAQAA
# AADTLQAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAlk
# ZXNjAAAA8AAAAHRyWFlaAAABZAAAABRnWFlaAAABeAAAABRiWFlaAAABjAAAABRyVFJDAAABoAAA
# AChnVFJDAAABoAAAAChiVFJDAAABoAAAACh3dHB0AAAByAAAABRjcHJ0AAAB3AAAADxtbHVjAAAA
# AAAAAAEAAAAMZW5VUwAAAFgAAAAcAHMAUgBHAEIAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAFhZWiAA
# AAAAAABvogAAOPUAAAOQWFlaIAAAAAAAAGKZAAC3hQAAGNpYWVogAAAAAAAAJKAAAA+EAAC2z3Bh
# cmEAAAAAAAQAAAACZmYAAPKnAAANWQAAE9AAAApbAAAAAAAAAABYWVogAAAAAAAA9tYAAQAAAADT
# LW1sdWMAAAAAAAAAAQAAAAxlblVTAAAAIAAAABwARwBvAG8AZwBsAGUAIABJAG4AYwAuACAAMgAw
# ADEANv/bAEMAAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEB
# AQEBAQEBAQEBAQEBAQEBAf/bAEMBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEBAQEB
# ...

# %%
im = Image.open("/home/venkateshiyer/handwritten_dataset/prod_dataset_iter4/100.png")
im.show()

# %%
print("This is string",pytesseract.image_to_string(im, config=''))
# Out:
# This is string

# %%
import cv2
img = cv2.imread("/home/venkateshiyer/handwritten_dataset/prod_dataset_iter4/100.png")
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.adaptiveThreshold(gry, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                            cv2.THRESH_BINARY_INV, 11, 4)
invert = cv2.bitwise_not(thr)
cv2.imshow("window_name", invert)
cv2.waitKey(0)
cv2.destroyAllWindows()
print("This is string",pytesseract.image_to_string(invert))
# Out:
# This is string

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(pytesseract.get_languages(config=''))
#
# AttributeError: module 'pytesseract' has no attribute 'get_languages'

# %%
print(pytesseract.image_to_string(Image.open("/home/venkateshiyer/handwritten_dataset/prod_dataset_iter4/100.png")))

# %%
import tensorflow as tf
model = tf.keras.models.load_model("/home/venkateshiyer/react-native-saral-sdk/ml_models/handwritten_digits/models/pre-trained_model/resnet_trained_model_digit_with_printed_v1_new_finetune_13_08_22_epoch_5.h5")
# Out:
# 2023-02-03 13:03:30.289682: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-02-03 13:03:30.289706: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-02-03 13:03:32.699729: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-02-03 13:03:32.699836: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ti-lap-492): /proc/driver/nvidia/version does not exist
# ...

# %%
# def pred_using_h5_digit(model, path, gt = None, prediction= None, wrong_results = None):
#     result = {}
#     wrong_results = {}
#     gt=[]
#     prediction = []
#     wrong_count=0
import glob
import cv2
import numpy as np 
path = "/home/venkateshiyer/handwritten_dataset/prod_dataset_iter4/*"
for img1 in sorted(glob.iglob(path)):
    img=cv2.imread(img1)
    print("This is img", img1)
    img=cv2.resize(img,(28,28))
    img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    cv2.imshow("window_name", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    img = img.astype('float32') / 255.
    img= np.reshape(img,(1,28,28,1))
    res=model.predict(img)
    pred=res[0].argmax(axis=0)
    cv2.imshow("window_name", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
#     ground_truth = int(img1.split('/')[-2])
#     gt.append(int(ground_truth))
#     prediction.append(pred)
#     result[img1] = pred
    print(pred)
    break
    
#     if pred!= int(ground_truth):
#         wrong_count+=1
#         wrong_results[img1] = pred
#     accuracy = (len(glob.glob(path))-wrong_count)/len(glob.glob(path))
#     return result, accuracy, gt, prediction, wrong_results
# Out:
# This is img /home/venkateshiyer/handwritten_dataset/prod_dataset_iter4/100.png

# %%
import cv2
import numpy as np 
img=cv2.imread("/home/venkateshiyer/handwritten_dataset/prod_dataset_iter4/106.png")
# print("This is img", img)
img=cv2.resize(img,(28,28))
img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# cv2.imshow("window_name", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
img = img.astype('float32') / 255.
img= np.reshape(img,(1,28,28,1))
res=model.predict(img)
pred=res[0].argmax(axis=0)
# cv2.imshow("window_name", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
print(pred)
# Out:
# 0
