# %% [markdown]
# # Some misclassifications by existing model

# %%
## 8 predicted as 0/9/3

# %% [markdown]
# ![marks04.png](attachment:marks04.png)

# %% [markdown]
# ![marks16.png](attachment:marks16.png)

# %% [markdown]
# ![marks_933_26812.png](attachment:marks_933_26812.png)

# %%
## 7 predicted as 1 and vice versa

# %% [markdown]
# ![marks_41897911304.png](attachment:marks_41897911304.png)

# %%
## 9 predicted as 5/3

# %% [markdown]
# ![marks_17566694706.png](attachment:marks_17566694706.png)

# %% [markdown]
# ![20506852326.png](attachment:20506852326.png)

# %% [markdown]
# # Some misclassfications by new model

# %%
# 8 predicted as 3

# %% [markdown]
# ![16144052807.png](attachment:16144052807.png)

# %% [markdown]
# ![33331338808.png](attachment:33331338808.png)

# %%
# 3 predicted as 9

# %% [markdown]
# ![trail_102.png](attachment:trail_102.png)
